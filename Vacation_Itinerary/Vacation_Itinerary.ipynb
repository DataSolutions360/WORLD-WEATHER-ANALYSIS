# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_Vacation.csv")
vacation_df.head(50)
# Out:
#     City_ID                    City Country  Max Temp  \
# 0         0              Bredasdorp      ZA     51.03
# 1         1                   Mezen      RU     32.59
# 2         2                   Pisco      PE     65.01
# 3         3                Tasiilaq      GL     35.76
# 4         4                  Atuona      PF     78.19
# 5         5               Upernavik      GL     19.74
# 6         6               Busselton      AU     63.55
# 7         7                    Hilo      US     82.13
# 8         8                   Vaini      TO     82.56
# 9         9                 Ushuaia      AR     51.46
# 10       10                Warragul      AU     58.10
# 11       11                  Nurota      UZ     68.13
# 12       12             Meadow Lake      US     85.48
# 13       13                  Barrow      US     30.22
# 14       14                 Rikitea      PF     76.24
# 15       15             East London      ZA     63.55
# 16       16                Zhigansk      RU     43.52
# 17       17            Port Lincoln      AU     59.29
# 18       18          Kulhudhuffushi      MV     83.37
# 19       19             Port Alfred      ZA     56.17
# 20       20                  Narsaq      GL     43.02
# 21       21                  Matara      LK     79.97
# 22       22  Sao Miguel Do Araguaia      BR     55.45
# 23       23               Jamestown      US     62.24
# 24       24            Ponta Do Sol      PT     66.83
# 25       25                Huicungo      PE     68.85
# 26       26                  Palana      RU     37.18
# 27       27             Villamontes      BO     51.98
# 28       28                Hermanus      ZA     55.69
# 29       29                  Moroto      UG     65.23
# 30       30         Haines Junction      CA     55.35
# 31       31            Punta Arenas      CL     41.11
# 32       33              Nikolskoye      RU     37.87
# 33       34                  Noumea      NC     80.58
# 34       35                 Morwell      AU     57.34
# 35       36                Klaksvik      FO     48.99
# 36       37                  Bethel      US     57.63
# 37       38                   Alofi      NU     78.69
# 38       39           Alta Floresta      BR     61.02
# 39       40                   Matay      EG     76.14
# 40       41              Skibbereen      IE     55.11
# 41       42                  Albany      US     57.67
# 42       43         Verkhnyaya Inta      RU     33.01
# 43       44                Coquimbo      CL     55.13
# 44       45            Puerto Ayora      EC     73.54
# 45       46         Charters Towers      AU     77.86
# 46       47                  Wufeng      CN     53.29
# 47       48              Port Blair      IN     78.84
# 48       49                   Bryan      US     83.88
# 49       50                 Isangel      VU     78.76
#
#         Weather Description      Lat       Lng  \
# 0          scattered clouds -34.5322   20.0403
# 1                light snow  65.8522   44.2400
# 2                      mist -13.7000  -76.2167
# 3           overcast clouds  65.6145  -37.6368
# 4                 clear sky  -9.8000 -139.0333
# 5                few clouds  72.7868  -56.1549
# 6           overcast clouds -33.6500  115.3333
# 7           overcast clouds  19.7297 -155.0900
# 8          scattered clouds -21.2000 -175.2000
# 9                 clear sky -54.8000  -68.3000
# 10                clear sky -38.1667  145.9333
# 11                clear sky  40.5614   65.6886
# 12                clear sky  34.8014 -106.5436
# 13          overcast clouds  71.2906 -156.7887
# 14            moderate rain -23.1203 -134.9692
# 15               light rain -33.0153   27.9116
# 16                clear sky  66.7697  123.3711
# 17            broken clouds -34.7333  135.8667
# 18          overcast clouds   6.6221   73.0700
# 19            moderate rain -33.5906   26.8910
# 20            broken clouds  60.9167  -46.0500
# 21          overcast clouds   5.9485   80.5353
# 22         scattered clouds -13.2750  -50.1628
# 23               few clouds  42.0970  -79.2353
# 24         scattered clouds  32.6667  -17.1000
# 25            broken clouds  -7.2833  -76.8000
# 26               light rain  59.1167  159.9667
# 27                clear sky -21.2500  -63.5000
# 28               few clouds -34.4187   19.2345
# 29          overcast clouds   2.5345   34.6666
# 30         scattered clouds  60.7522 -137.5108
# 31  light intensity drizzle -53.1500  -70.9167
# 32            broken clouds  59.7035   30.7861
# 33          overcast clouds -22.2763  166.4572
# 34                clear sky -38.2333  146.4000
# 35          overcast clouds  62.2266   -6.5890
# 36                clear sky  41.3712  -73.4140
# 37  light intensity drizzle -19.0595 -169.9187
# 38            broken clouds  -9.8756  -56.0861
# 39            broken clouds  28.4190   30.7792
# 40            broken clouds  51.5500   -9.2667
# 41          overcast clouds  42.6001  -73.9662
# 42          overcast clouds  65.9811   60.3094
# 43                clear sky -29.9533  -71.3436
# 44         scattered clouds  -0.7393  -90.3518
# 45                clear sky -20.1000  146.2667
# 46          overcast clouds  27.4500  104.8333
# 47          overcast clouds  11.6667   92.7500
# 48                clear sky  30.6744  -96.3700
# 49     heavy intensity rain -19.5500  169.2667
#
#                                            Hotel Name
# 0                            Bredasdorp Country Manor
# 1                                Gostevoy Dom Everest
# 2                            Hotel San Isidro Oficial
# 3                                       The Red House
# 4                                         Villa Enata
# 5                                   Café de Upernavik
# 6                             Observatory Guest House
# 7                                 Hilo Hawaiian Hotel
# 8                                 Keleti Beach Resort
# 9                                     Albatross Hotel
# 10                      Comfort Inn & Suites Warragul
# 11                  Guest House Ruslan Nurata & Tours
# 12                                 TumbleWeed RV Park
# 13                                     King Eider Inn
# 14                                    People ThankYou
# 15                                            Tu Casa
# 16                        Gostinichnyy Kompleks Aylgy
# 17                                 Port Lincoln Hotel
# 18                                Haajy Guest House 1
# 19                                 The Halyards Hotel
# 20                                    Sleep In Narsaq
# 21                             Amaloh Boutique Resort
# 22                             Hotel Executivo Palace
# 23                     Hampton Inn & Suites Jamestown
# 24                                     Hotel do Campo
# 25                                  Gran Pajaten Trek
# 26                                            Chikago
# 27                                       Hotel Raldes
# 28                         Misty Waves Boutique Hotel
# 29                   Kara-Tunga, Karamoja Safari Camp
# 30                                       Parkside Inn
# 31                                         Hotel Hain
# 32                            Tourist House - Sablino
# 33                                     Hôtel Le Lagon
# 34                               Always Welcome Motel
# 35                                       Airbnb rooms
# 36                      Courtyard by Marriott Danbury
# 37                                      Taloa Heights
# 38                           Floresta Amazonica Hotel
# 39                                         Nag Aespen
# 40                                The West Cork Hotel
# 41                                                NaN
# 42                                                NaN
# 43                                     Hotel San Juan
# 44                          Finch Bay Galapagos Hotel
# 45                         Cattleman's Rest Motor Inn
# 46                                               中山宾馆
# 47  Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 48         Best Western Premier Bryan College Station
# 49                                        Tanna Lodge

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

<d1>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<d1>Weather Description</dt><dd>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
<d1>

"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center = (30.0, 31.0), zoom_level = 1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Meadow Lake"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Jamestown"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Roma"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Ottumwa"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Berea"]
vacation_stop1
# Out:
#      City_ID  City Country  Max Temp Weather Description      Lat      Lng  \
# 630      636  Roma      US     53.96    scattered clouds  43.2128 -75.4557
#
#                   Hotel Name
# 630  Wingate By Wyndham Rome

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps.datasets

gmaps.configure(api_key = g_key)

fig = gmaps.figure()

driving_map = gmaps.directions_layer(start,end,waypoints = [stop1, stop2, stop3],travel_mode = "DRIVING")
fig.add_layer(driving_map)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp Weather Description      Lat  \
# 0       12  Meadow Lake      US     85.48           clear sky  34.8014
# 1      636         Roma      US     53.96    scattered clouds  43.2128
# 2      635      Ottumwa      US     79.36           clear sky  41.0200
# 3      631        Berea      US     76.26       broken clouds  41.3662
#
#         Lng                     Hotel Name
# 0 -106.5436             TumbleWeed RV Park
# 1  -75.4557        Wingate By Wyndham Rome
# 2  -92.4113            Hampton Inn Ottumwa
# 3  -81.8543  Comfort Inn Cleveland Airport

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<d1>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<d1>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Weather Description} and {Max Temp} °F</dd>
<d1>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]
#hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]

fig = gmaps.figure(center = (30.0, 31.0), zoom_level = 1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
