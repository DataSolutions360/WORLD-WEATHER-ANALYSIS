# %%
# Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
# Create a set of random latitude and longitude combinations 
lats = np.random.uniform(90.000, -90.000, size = 2000)
lngs = np.random.uniform(180.000, -180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities= []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city to confirm sufficient count 
len(cities)
# Out:
# 700

# %%
# Importing weather API key
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Make an API call
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
# Loop through all the cities in our list
for i in range(len(cities)):
    
    # Group the cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + cities[i]

# %%
cities
# Out:
# ['christchurch',
#  'plastun',
#  'kodiak',
#  'new norfolk',
#  'khatanga',
#  'ossora',
#  'cape town',
#  'walvis bay',
#  'guekedou',
#  'bambous virieux',
#  'barentsburg',
#  'barrow',
#  'dingle',
#  'dunedin',
#  'qaanaaq',
#  'taolanaro',
#  'bargal',
#  'lebu',
#  'luz',
#  'port alfred',
#  'busselton',
#  'albany',
#  'bluff',
#  'tuktoyaktuk',
#  'lanzhou',
#  'road town',
#  'hilo',
#  'mataura',
#  'yamada',
#  'erzin',
#  'buraydah',
#  'eyl',
#  'east london',
#  'rio claro',
#  'san nicolas',
#  'punta arenas',
#  'cidreira',
#  'avarua',
#  'saint-philippe',
#  'codrington',
#  'hobart',
#  'sao filipe',
#  'trat',
#  'santa isabel do rio negro',
#  'te anau',
#  'stepantsevo',
#  'ribeira grande',
#  'boa vista',
#  'mahebourg',
#  'dudinka',
#  'san isidro',
#  'castro',
#  'rikitea',
#  'vila franca do campo',
#  'altay',
#  'upernavik',
#  'zhangye',
#  'hermanus',
#  'djenne',
#  'arraial do cabo',
#  'ushuaia',
#  'butaritari',
#  'kasra',
#  'bolungarvik',
#  'chokurdakh',
#  'fairview',
#  'ostrovnoy',
#  'puerto leguizamo',
#  'jamestown',
#  'fortuna',
#  'yerbogachen',
#  'dongsheng',
#  'lagoa',
#  'mangan',
#  'airai',
#  'miandrivazo',
#  'sorong',
#  'nuuk',
#  'illoqqortoormiut',
#  'grand river south east',
#  'puerto cabezas',
#  'fuerte olimpo',
#  'alofi',
#  'spirovo',
#  'cairns',
#  'umea',
#  'dehloran',
#  'longyearbyen',
#  'gunjur',
#  'isangel',
#  'provideniya',
#  'nikolskoye',
#  'leo',
#  'ponta do sol',
#  'awjilah',
#  'gat',
#  'salalah',
#  'tuatapere',
#  'port elizabeth',
#  'oneida',
#  'kedrovka',
#  'bundaberg',
#  'zhanaozen',
#  'saskylakh',
#  'vaini',
#  'laguna',
#  'kungurtug',
#  'mayor pablo lagerenza',
#  'boysun',
#  'vardo',
#  'srednekolymsk',
#  'winslow',
#  'toguchin',
#  'riviere-au-renard',
#  'kapaa',
#  'palu',
#  'katsuura',
#  'port lincoln',
#  'rungata',
#  'sika',
#  'bredasdorp',
#  'celestun',
#  'nizhneyansk',
#  'grand gaube',
#  'xuchang',
#  'trelew',
#  'paidha',
#  'sabang',
#  'kruisfontein',
#  'bengkulu',
#  'tumannyy',
#  'karlstad',
#  'bawku',
#  'vostok',
#  'hithadhoo',
#  'puerto ayora',
#  'louisbourg',
#  'vilhena',
#  'faanui',
#  'caravelas',
#  'ust-nera',
#  'mar del plata',
#  'tasiilaq',
#  'torbay',
#  'anzio',
#  'acarau',
#  'constitucion',
#  'perth',
#  'vogan',
#  'great yarmouth',
#  'serebryanyy bor',
#  'iracoubo',
#  'khani',
#  'port blair',
#  'xacmaz',
#  'guerrero negro',
#  'vanimo',
#  'varkaus',
#  'carutapera',
#  'yurty',
#  'yermekeyevo',
#  'smirnykh',
#  'rongcheng',
#  'cherskiy',
#  'neyshabur',
#  'norrtalje',
#  'pevek',
#  'cockburn town',
#  'dekernes',
#  'banda aceh',
#  'biak',
#  'lorengau',
#  'ojinaga',
#  'lillehammer',
#  'san policarpo',
#  'ancud',
#  'denpasar',
#  'bethel',
#  'cap-aux-meules',
#  'tahe',
#  'vestmannaeyjar',
#  'harper',
#  'jaypur',
#  'hasaki',
#  'severo-kurilsk',
#  'karratha',
#  'qasigiannguit',
#  'changli',
#  'doha',
#  'tautira',
#  'avera',
#  'bone',
#  'union',
#  'demidov',
#  'dikson',
#  'goderich',
#  'telimele',
#  'bathsheba',
#  'nakamura',
#  'thompson',
#  'georgetown',
#  'fengcheng',
#  'saint george',
#  'zhezkazgan',
#  'xiamen',
#  'porto walter',
#  'esperance',
#  'la ronge',
#  'uyuni',
#  'lebowakgomo',
#  'atuona',
#  'churachandpur',
#  'alta floresta',
#  'mayari',
#  'guadalajara',
#  'paamiut',
#  'nome',
#  'coffs harbour',
#  'gagarin',
#  'richards bay',
#  'zamora',
#  'ahtopol',
#  'jalu',
#  'palabuhanratu',
#  'shelburne',
#  'eregli',
#  'tilichiki',
#  'clinton',
#  'lasa',
#  'attawapiskat',
#  'coihaique',
#  'yar-sale',
#  'souillac',
#  'mys shmidta',
#  'thinadhoo',
#  'naron',
#  'phan thiet',
#  'roald',
#  'santa maria',
#  'udachnyy',
#  'alotau',
#  'morris',
#  'batsfjord',
#  'margate',
#  'san patricio',
#  'ust-maya',
#  'fort saint james',
#  'burkhala',
#  'ixtapa',
#  'usinsk',
#  'chuy',
#  'nhulunbuy',
#  'vorchdorf',
#  'half moon bay',
#  'sentyabrskiy',
#  'sioux lookout',
#  'natal',
#  'yellowknife',
#  'flinders',
#  'darhan',
#  'mount isa',
#  'maniitsoq',
#  'korla',
#  'carballo',
#  'rundu',
#  'alagoa grande',
#  'sitka',
#  'alberton',
#  'kiunga',
#  'namatanai',
#  'zaranj',
#  'san ramon',
#  'koutiala',
#  'muscatine',
#  'saint-francois',
#  'norman wells',
#  'iqaluit',
#  'wahran',
#  'mutoko',
#  'benghazi',
#  'vao',
#  'carnarvon',
#  'narrabri',
#  'patacamaya',
#  'saldanha',
#  'jinan',
#  'strezhevoy',
#  'waipawa',
#  'pisco',
#  'tiksi',
#  'ngunguru',
#  'fernley',
#  'cabo san lucas',
#  'nanortalik',
#  'klaksvik',
#  'murray bridge',
#  'oktyabrskiy',
#  'kahului',
#  'batemans bay',
#  'sisophon',
#  'namibe',
#  'yulara',
#  'maghama',
#  'aykhal',
#  'hurricane',
#  'semnan',
#  'leningradskiy',
#  'knysna',
#  'san andres',
#  'ipil',
#  'sola',
#  'bucerias',
#  'pavlogradka',
#  'tarabuco',
#  'belushya guba',
#  'saint-pierre',
#  'jiddah',
#  'panama city',
#  'geraldton',
#  'karaul',
#  'yeppoon',
#  'kurilsk',
#  'lompoc',
#  'touros',
#  'joshimath',
#  'szprotawa',
#  'victoria',
#  'balaipungut',
#  'puerto quijarro',
#  'sorvag',
#  'sao jose da coroa grande',
#  'puerto baquerizo moreno',
#  'antalaha',
#  'nyurba',
#  'phalodi',
#  'yinchuan',
#  'ketchikan',
#  'bakal',
#  'chulumani',
#  'san quintin',
#  'nemuro',
#  'mandan',
#  'tiarei',
#  'kavieng',
#  'watsa',
#  'qiyang',
#  'sao joao da barra',
#  'mandalay',
#  'killybegs',
#  'ankazobe',
#  'ryotsu',
#  'catamarca',
#  'juneau',
#  'rawannawi',
#  'gewane',
#  'naze',
#  'oxford',
#  'tallahassee',
#  'churapcha',
#  'khipro',
#  'blagoyevo',
#  'san vicente',
#  'ninghai',
#  'sala',
#  'matara',
#  'anadyr',
#  'tsihombe',
#  'lolua',
#  'acari',
#  'halalo',
#  'kaitangata',
#  'antofagasta',
#  'chagda',
#  'houma',
#  'lancut',
#  'tezu',
#  'clyde river',
#  'chicama',
#  'luderitz',
#  'nioro',
#  'kayerkan',
#  'rabo de peixe',
#  'micheweni',
#  'samusu',
#  'kaeo',
#  'soure',
#  'saint-georges',
#  'waspan',
#  'rawson',
#  'chitral',
#  'loandjili',
#  'ilulissat',
#  'umm lajj',
#  'coquimbo',
#  'higuey',
#  'bandarbeyla',
#  'comodoro rivadavia',
#  'manokwari',
#  'payo',
#  'katobu',
#  'egvekinot',
#  'saint anthony',
#  'port hedland',
#  'ucluelet',
#  'uberaba',
#  'calama',
#  'aklavik',
#  'presidencia roque saenz pena',
#  'lensk',
#  'yima',
#  'bahar',
#  'mayo',
#  'alyangula',
#  'thunder bay',
#  'piojo',
#  'kochevo',
#  'kosa',
#  'yekaterinovka',
#  'hohhot',
#  'vaitupu',
#  'sur',
#  'athabasca',
#  'whitchurch-stouffville',
#  'san rafael del sur',
#  'komsomolskiy',
#  'miedzychod',
#  'yuci',
#  'oranjemund',
#  'amderma',
#  'cutro',
#  'tayu',
#  'mudon',
#  'erenhot',
#  'gavle',
#  'bokspits',
#  'atambua',
#  'achisay',
#  'mandalgovi',
#  'cap malheureux',
#  'manoel urbano',
#  'garowe',
#  'sangar',
#  'qeshm',
#  'tabas',
#  'jumla',
#  'nantucket',
#  'nouadhibou',
#  'konevo',
#  'amuntai',
#  'floro',
#  'fortuna foothills',
#  'talnakh',
#  'la palma',
#  'marabba',
#  'hit',
#  'arlit',
#  'wajima',
#  'sovetskiy',
#  'okhotsk',
#  'mount gambier',
#  'kaduna',
#  'beringovskiy',
#  'imeni zhelyabova',
#  'armacao dos buzios',
#  'acajutla',
#  'meulaboh',
#  'barabinsk',
#  'dosso',
#  'grindavik',
#  'ondorhaan',
#  'bogovarovo',
#  'la orilla',
#  'yacuiba',
#  'burhar',
#  'kamyshin',
#  'esmeraldas',
#  'inhambane',
#  'vestmanna',
#  'ozernovskiy',
#  'maumere',
#  'camapua',
#  'goroka',
#  'bubaque',
#  'sorland',
#  'sehithwa',
#  'tawkar',
#  'baykit',
#  'poronaysk',
#  'kununurra',
#  'morshansk',
#  'brownsville',
#  'kisangani',
#  'san carlos de bariloche',
#  'puerto escondido',
#  'bilibino',
#  'barahona',
#  'methven',
#  'kommunisticheskiy',
#  'petropavlovsk-kamchatskiy',
#  'saleaula',
#  'fort frances',
#  'tabiauea',
#  'honiara',
#  'monrovia',
#  'nerchinskiy zavod',
#  'the valley',
#  'straumen',
#  'kailua',
#  'hasanabad',
#  'novobirilyussy',
#  'calvia',
#  'flin flon',
#  'emba',
#  'marcona',
#  'brodokalmak',
#  'shihezi',
#  'rincon',
#  'talaya',
#  'belomorsk',
#  'gazli',
#  'glendora',
#  'yabelo',
#  'stanger',
#  'port hueneme',
#  'capalonga',
#  'berlevag',
#  'havelock',
#  'demyanovo',
#  'severo-yeniseyskiy',
#  'palpa',
#  'adamas',
#  'maceio',
#  'lubbock',
#  'samalaeulu',
#  'tura',
#  'takoradi',
#  'nikel',
#  'pedasi',
#  'amapa',
#  'kizner',
#  'artyk',
#  'artyom',
#  'port hardy',
#  'henties bay',
#  'phuket',
#  'marsh harbour',
#  'yashan',
#  'gracac',
#  'chubbuck',
#  'brandon',
#  'wahiawa',
#  'husavik',
#  'itoman',
#  'kutum',
#  'jurm',
#  'bismarck',
#  'onguday',
#  'olinda',
#  'hashtrud',
#  'borovskoy',
#  'sarangani',
#  'labuan',
#  'lavrentiya',
#  'anori',
#  'san julian',
#  'padang',
#  'kloulklubed',
#  'shellbrook',
#  'chernyy yar',
#  'azangaro',
#  'narsaq',
#  'broken hill',
#  'bentiu',
#  'kendari',
#  'krasnoselkup',
#  'hualmay',
#  'baherden',
#  'salinas',
#  'bushehr',
#  'vila',
#  'quatre cocos',
#  'adrar',
#  'abu jubayhah',
#  'tromso',
#  'verkhnyaya inta',
#  'leiyang',
#  'rajula',
#  'port keats',
#  'ust-uda',
#  'greaca',
#  'vitim',
#  'gigmoto',
#  'kinshasa',
#  'papasquiaro',
#  'ahuimanu',
#  'grand island',
#  'linjiang',
#  'wanlaweyn',
#  'arrifes',
#  'palmer',
#  'prince rupert',
#  'umzimvubu',
#  'khovu-aksy',
#  'jalingo',
#  'suntar',
#  'bababe',
#  'dolbeau',
#  'hudson bay',
#  'novikovo',
#  'atar',
#  'launceston',
#  'santa cruz',
#  'assiniboia',
#  'sinnamary',
#  'hami',
#  'krasnaya gora',
#  'saryshagan',
#  'davenport',
#  'jaffna',
#  'xichang',
#  'ouango',
#  'kudamatsu',
#  'serik',
#  'ambilobe',
#  'necochea',
#  'tete',
#  'hambantota',
#  'santona',
#  'burns lake',
#  'abu samrah',
#  'sungaipenuh',
#  'ulladulla',
#  'aflu',
#  'karamay',
#  'punta gorda',
#  'saint-augustin',
#  'bodmin',
#  'sulya',
#  'jaisalmer',
#  'shimoda',
#  'kieta',
#  'berdigestyakh',
#  'ponta delgada',
#  'bloemfontein',
#  'westport',
#  'neftcala',
#  'palembang',
#  'salaya',
#  'garoua boulai',
#  'cordoba',
#  'pillaro',
#  'pangnirtung',
#  'jiroft',
#  'nishihara',
#  'kardymovo',
#  'kilakarai',
#  'lebedyan',
#  'ahipara',
#  'tessalit',
#  'meadow lake',
#  'porgera',
#  'prescott',
#  'mahajanga',
#  'pacific grove',
#  'mushie',
#  'hamilton',
#  'broome',
#  'puro',
#  'jieshi',
#  'billings',
#  'mahanoro',
#  'machico',
#  'mandurah',
#  'fairbanks',
#  'deputatskiy',
#  'ledec',
#  'breves',
#  'adre',
#  'hofn',
#  'acapulco',
#  'herat',
#  'port augusta',
#  'bechem',
#  'eureka',
#  'labuhan',
#  'general roca',
#  'zyryanka',
#  'baturaja',
#  'vredendal',
#  'alice springs',
#  'chatsu',
#  'sylva',
#  'tashtyp',
#  'bosaso',
#  'novo aripuana',
#  'charters towers',
#  'coos bay',
#  'shintomi',
#  'vila do maio',
#  'tabou']

# %%
# Loop through all the cities in the list    
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
         # Parse the JSON and retreive data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H-%M-%S")
        
        # Append the city infomration into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description})
        
# If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found. Skipping...")
        pass
    
# Indicate that Data Loading is Complete
print("--------------------------------")
print("Data Retreival Complete         ")
print("--------------------------------")
# Out:
# Processing Record 1 of Set 14 | christchurch
# Processing Record 2 of Set 14 | plastun
# Processing Record 3 of Set 14 | kodiak
# Processing Record 4 of Set 14 | new norfolk
# Processing Record 5 of Set 14 | khatanga
# Processing Record 6 of Set 14 | ossora
# Processing Record 7 of Set 14 | cape town
# Processing Record 8 of Set 14 | walvis bay
# Processing Record 9 of Set 14 | guekedou
# City not found. Skipping...
# Processing Record 10 of Set 14 | bambous virieux
# Processing Record 11 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 14 | barrow
# Processing Record 13 of Set 14 | dingle
# Processing Record 14 of Set 14 | dunedin
# Processing Record 15 of Set 14 | qaanaaq
# Processing Record 16 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 14 | lebu
# Processing Record 19 of Set 14 | luz
# Processing Record 20 of Set 14 | port alfred
# Processing Record 21 of Set 14 | busselton
# Processing Record 22 of Set 14 | albany
# Processing Record 23 of Set 14 | bluff
# Processing Record 24 of Set 14 | tuktoyaktuk
# Processing Record 25 of Set 14 | lanzhou
# Processing Record 26 of Set 14 | road town
# Processing Record 27 of Set 14 | hilo
# Processing Record 28 of Set 14 | mataura
# Processing Record 29 of Set 14 | yamada
# Processing Record 30 of Set 14 | erzin
# Processing Record 31 of Set 14 | buraydah
# Processing Record 32 of Set 14 | eyl
# Processing Record 33 of Set 14 | east london
# Processing Record 34 of Set 14 | rio claro
# Processing Record 35 of Set 14 | san nicolas
# Processing Record 36 of Set 14 | punta arenas
# Processing Record 37 of Set 14 | cidreira
# Processing Record 38 of Set 14 | avarua
# Processing Record 39 of Set 14 | saint-philippe
# Processing Record 40 of Set 14 | codrington
# Processing Record 41 of Set 14 | hobart
# Processing Record 42 of Set 14 | sao filipe
# Processing Record 43 of Set 14 | trat
# Processing Record 44 of Set 14 | santa isabel do rio negro
# Processing Record 45 of Set 14 | te anau
# Processing Record 46 of Set 14 | stepantsevo
# Processing Record 47 of Set 14 | ribeira grande
# Processing Record 48 of Set 14 | boa vista
# Processing Record 49 of Set 14 | mahebourg
# Processing Record 50 of Set 14 | dudinka
# Processing Record 1 of Set 15 | san isidro
# Processing Record 2 of Set 15 | castro
# Processing Record 3 of Set 15 | rikitea
# Processing Record 4 of Set 15 | vila franca do campo
# Processing Record 5 of Set 15 | altay
# Processing Record 6 of Set 15 | upernavik
# Processing Record 7 of Set 15 | zhangye
# Processing Record 8 of Set 15 | hermanus
# Processing Record 9 of Set 15 | djenne
# Processing Record 10 of Set 15 | arraial do cabo
# Processing Record 11 of Set 15 | ushuaia
# Processing Record 12 of Set 15 | butaritari
# Processing Record 13 of Set 15 | kasra
# City not found. Skipping...
# Processing Record 14 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 15 | chokurdakh
# Processing Record 16 of Set 15 | fairview
# Processing Record 17 of Set 15 | ostrovnoy
# Processing Record 18 of Set 15 | puerto leguizamo
# Processing Record 19 of Set 15 | jamestown
# Processing Record 20 of Set 15 | fortuna
# Processing Record 21 of Set 15 | yerbogachen
# Processing Record 22 of Set 15 | dongsheng
# Processing Record 23 of Set 15 | lagoa
# Processing Record 24 of Set 15 | mangan
# Processing Record 25 of Set 15 | airai
# Processing Record 26 of Set 15 | miandrivazo
# Processing Record 27 of Set 15 | sorong
# Processing Record 28 of Set 15 | nuuk
# Processing Record 29 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 15 | puerto cabezas
# Processing Record 32 of Set 15 | fuerte olimpo
# Processing Record 33 of Set 15 | alofi
# Processing Record 34 of Set 15 | spirovo
# Processing Record 35 of Set 15 | cairns
# Processing Record 36 of Set 15 | umea
# Processing Record 37 of Set 15 | dehloran
# Processing Record 38 of Set 15 | longyearbyen
# Processing Record 39 of Set 15 | gunjur
# Processing Record 40 of Set 15 | isangel
# Processing Record 41 of Set 15 | provideniya
# Processing Record 42 of Set 15 | nikolskoye
# Processing Record 43 of Set 15 | leo
# Processing Record 44 of Set 15 | ponta do sol
# Processing Record 45 of Set 15 | awjilah
# Processing Record 46 of Set 15 | gat
# Processing Record 47 of Set 15 | salalah
# Processing Record 48 of Set 15 | tuatapere
# Processing Record 49 of Set 15 | port elizabeth
# Processing Record 50 of Set 15 | oneida
# Processing Record 1 of Set 16 | kedrovka
# Processing Record 2 of Set 16 | bundaberg
# Processing Record 3 of Set 16 | zhanaozen
# Processing Record 4 of Set 16 | saskylakh
# Processing Record 5 of Set 16 | vaini
# Processing Record 6 of Set 16 | laguna
# Processing Record 7 of Set 16 | kungurtug
# Processing Record 8 of Set 16 | mayor pablo lagerenza
# Processing Record 9 of Set 16 | boysun
# Processing Record 10 of Set 16 | vardo
# Processing Record 11 of Set 16 | srednekolymsk
# Processing Record 12 of Set 16 | winslow
# Processing Record 13 of Set 16 | toguchin
# Processing Record 14 of Set 16 | riviere-au-renard
# Processing Record 15 of Set 16 | kapaa
# Processing Record 16 of Set 16 | palu
# Processing Record 17 of Set 16 | katsuura
# Processing Record 18 of Set 16 | port lincoln
# Processing Record 19 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 16 | sika
# Processing Record 21 of Set 16 | bredasdorp
# Processing Record 22 of Set 16 | celestun
# Processing Record 23 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 16 | grand gaube
# Processing Record 25 of Set 16 | xuchang
# Processing Record 26 of Set 16 | trelew
# Processing Record 27 of Set 16 | paidha
# Processing Record 28 of Set 16 | sabang
# Processing Record 29 of Set 16 | kruisfontein
# Processing Record 30 of Set 16 | bengkulu
# Processing Record 31 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 16 | karlstad
# Processing Record 33 of Set 16 | bawku
# Processing Record 34 of Set 16 | vostok
# Processing Record 35 of Set 16 | hithadhoo
# Processing Record 36 of Set 16 | puerto ayora
# Processing Record 37 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 16 | vilhena
# Processing Record 39 of Set 16 | faanui
# Processing Record 40 of Set 16 | caravelas
# Processing Record 41 of Set 16 | ust-nera
# Processing Record 42 of Set 16 | mar del plata
# Processing Record 43 of Set 16 | tasiilaq
# Processing Record 44 of Set 16 | torbay
# Processing Record 45 of Set 16 | anzio
# Processing Record 46 of Set 16 | acarau
# Processing Record 47 of Set 16 | constitucion
# Processing Record 48 of Set 16 | perth
# Processing Record 49 of Set 16 | vogan
# Processing Record 50 of Set 16 | great yarmouth
# Processing Record 1 of Set 17 | serebryanyy bor
# Processing Record 2 of Set 17 | iracoubo
# Processing Record 3 of Set 17 | khani
# Processing Record 4 of Set 17 | port blair
# Processing Record 5 of Set 17 | xacmaz
# Processing Record 6 of Set 17 | guerrero negro
# Processing Record 7 of Set 17 | vanimo
# Processing Record 8 of Set 17 | varkaus
# Processing Record 9 of Set 17 | carutapera
# Processing Record 10 of Set 17 | yurty
# Processing Record 11 of Set 17 | yermekeyevo
# Processing Record 12 of Set 17 | smirnykh
# Processing Record 13 of Set 17 | rongcheng
# Processing Record 14 of Set 17 | cherskiy
# Processing Record 15 of Set 17 | neyshabur
# Processing Record 16 of Set 17 | norrtalje
# Processing Record 17 of Set 17 | pevek
# Processing Record 18 of Set 17 | cockburn town
# Processing Record 19 of Set 17 | dekernes
# Processing Record 20 of Set 17 | banda aceh
# Processing Record 21 of Set 17 | biak
# Processing Record 22 of Set 17 | lorengau
# Processing Record 23 of Set 17 | ojinaga
# Processing Record 24 of Set 17 | lillehammer
# Processing Record 25 of Set 17 | san policarpo
# Processing Record 26 of Set 17 | ancud
# Processing Record 27 of Set 17 | denpasar
# Processing Record 28 of Set 17 | bethel
# Processing Record 29 of Set 17 | cap-aux-meules
# Processing Record 30 of Set 17 | tahe
# Processing Record 31 of Set 17 | vestmannaeyjar
# Processing Record 32 of Set 17 | harper
# Processing Record 33 of Set 17 | jaypur
# Processing Record 34 of Set 17 | hasaki
# Processing Record 35 of Set 17 | severo-kurilsk
# Processing Record 36 of Set 17 | karratha
# Processing Record 37 of Set 17 | qasigiannguit
# Processing Record 38 of Set 17 | changli
# Processing Record 39 of Set 17 | doha
# Processing Record 40 of Set 17 | tautira
# Processing Record 41 of Set 17 | avera
# Processing Record 42 of Set 17 | bone
# Processing Record 43 of Set 17 | union
# Processing Record 44 of Set 17 | demidov
# Processing Record 45 of Set 17 | dikson
# Processing Record 46 of Set 17 | goderich
# Processing Record 47 of Set 17 | telimele
# Processing Record 48 of Set 17 | bathsheba
# Processing Record 49 of Set 17 | nakamura
# Processing Record 50 of Set 17 | thompson
# Processing Record 1 of Set 18 | georgetown
# Processing Record 2 of Set 18 | fengcheng
# Processing Record 3 of Set 18 | saint george
# Processing Record 4 of Set 18 | zhezkazgan
# Processing Record 5 of Set 18 | xiamen
# Processing Record 6 of Set 18 | porto walter
# Processing Record 7 of Set 18 | esperance
# Processing Record 8 of Set 18 | la ronge
# Processing Record 9 of Set 18 | uyuni
# Processing Record 10 of Set 18 | lebowakgomo
# Processing Record 11 of Set 18 | atuona
# Processing Record 12 of Set 18 | churachandpur
# Processing Record 13 of Set 18 | alta floresta
# Processing Record 14 of Set 18 | mayari
# City not found. Skipping...
# Processing Record 15 of Set 18 | guadalajara
# Processing Record 16 of Set 18 | paamiut
# Processing Record 17 of Set 18 | nome
# Processing Record 18 of Set 18 | coffs harbour
# Processing Record 19 of Set 18 | gagarin
# Processing Record 20 of Set 18 | richards bay
# Processing Record 21 of Set 18 | zamora
# Processing Record 22 of Set 18 | ahtopol
# Processing Record 23 of Set 18 | jalu
# Processing Record 24 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 18 | shelburne
# Processing Record 26 of Set 18 | eregli
# Processing Record 27 of Set 18 | tilichiki
# Processing Record 28 of Set 18 | clinton
# Processing Record 29 of Set 18 | lasa
# Processing Record 30 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 18 | coihaique
# Processing Record 32 of Set 18 | yar-sale
# Processing Record 33 of Set 18 | souillac
# Processing Record 34 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 18 | thinadhoo
# Processing Record 36 of Set 18 | naron
# Processing Record 37 of Set 18 | phan thiet
# Processing Record 38 of Set 18 | roald
# Processing Record 39 of Set 18 | santa maria
# Processing Record 40 of Set 18 | udachnyy
# Processing Record 41 of Set 18 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 18 | morris
# Processing Record 43 of Set 18 | batsfjord
# Processing Record 44 of Set 18 | margate
# Processing Record 45 of Set 18 | san patricio
# Processing Record 46 of Set 18 | ust-maya
# Processing Record 47 of Set 18 | fort saint james
# Processing Record 48 of Set 18 | burkhala
# City not found. Skipping...
# Processing Record 49 of Set 18 | ixtapa
# Processing Record 50 of Set 18 | usinsk
# Processing Record 1 of Set 19 | chuy
# Processing Record 2 of Set 19 | nhulunbuy
# Processing Record 3 of Set 19 | vorchdorf
# Processing Record 4 of Set 19 | half moon bay
# Processing Record 5 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 19 | sioux lookout
# Processing Record 7 of Set 19 | natal
# Processing Record 8 of Set 19 | yellowknife
# Processing Record 9 of Set 19 | flinders
# Processing Record 10 of Set 19 | darhan
# Processing Record 11 of Set 19 | mount isa
# Processing Record 12 of Set 19 | maniitsoq
# Processing Record 13 of Set 19 | korla
# Processing Record 14 of Set 19 | carballo
# Processing Record 15 of Set 19 | rundu
# Processing Record 16 of Set 19 | alagoa grande
# Processing Record 17 of Set 19 | sitka
# Processing Record 18 of Set 19 | alberton
# Processing Record 19 of Set 19 | kiunga
# Processing Record 20 of Set 19 | namatanai
# Processing Record 21 of Set 19 | zaranj
# Processing Record 22 of Set 19 | san ramon
# Processing Record 23 of Set 19 | koutiala
# Processing Record 24 of Set 19 | muscatine
# Processing Record 25 of Set 19 | saint-francois
# Processing Record 26 of Set 19 | norman wells
# Processing Record 27 of Set 19 | iqaluit
# Processing Record 28 of Set 19 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 19 | mutoko
# Processing Record 30 of Set 19 | benghazi
# Processing Record 31 of Set 19 | vao
# Processing Record 32 of Set 19 | carnarvon
# Processing Record 33 of Set 19 | narrabri
# Processing Record 34 of Set 19 | patacamaya
# Processing Record 35 of Set 19 | saldanha
# Processing Record 36 of Set 19 | jinan
# Processing Record 37 of Set 19 | strezhevoy
# Processing Record 38 of Set 19 | waipawa
# Processing Record 39 of Set 19 | pisco
# Processing Record 40 of Set 19 | tiksi
# Processing Record 41 of Set 19 | ngunguru
# Processing Record 42 of Set 19 | fernley
# Processing Record 43 of Set 19 | cabo san lucas
# Processing Record 44 of Set 19 | nanortalik
# Processing Record 45 of Set 19 | klaksvik
# Processing Record 46 of Set 19 | murray bridge
# Processing Record 47 of Set 19 | oktyabrskiy
# Processing Record 48 of Set 19 | kahului
# Processing Record 49 of Set 19 | batemans bay
# Processing Record 50 of Set 19 | sisophon
# Processing Record 1 of Set 20 | namibe
# Processing Record 2 of Set 20 | yulara
# Processing Record 3 of Set 20 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 20 | aykhal
# Processing Record 5 of Set 20 | hurricane
# Processing Record 6 of Set 20 | semnan
# Processing Record 7 of Set 20 | leningradskiy
# Processing Record 8 of Set 20 | knysna
# Processing Record 9 of Set 20 | san andres
# Processing Record 10 of Set 20 | ipil
# Processing Record 11 of Set 20 | sola
# Processing Record 12 of Set 20 | bucerias
# Processing Record 13 of Set 20 | pavlogradka
# Processing Record 14 of Set 20 | tarabuco
# Processing Record 15 of Set 20 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 20 | saint-pierre
# Processing Record 17 of Set 20 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 20 | panama city
# Processing Record 19 of Set 20 | geraldton
# Processing Record 20 of Set 20 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 20 | yeppoon
# Processing Record 22 of Set 20 | kurilsk
# Processing Record 23 of Set 20 | lompoc
# Processing Record 24 of Set 20 | touros
# Processing Record 25 of Set 20 | joshimath
# Processing Record 26 of Set 20 | szprotawa
# Processing Record 27 of Set 20 | victoria
# Processing Record 28 of Set 20 | balaipungut
# Processing Record 29 of Set 20 | puerto quijarro
# Processing Record 30 of Set 20 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 20 | sao jose da coroa grande
# Processing Record 32 of Set 20 | puerto baquerizo moreno
# Processing Record 33 of Set 20 | antalaha
# Processing Record 34 of Set 20 | nyurba
# Processing Record 35 of Set 20 | phalodi
# Processing Record 36 of Set 20 | yinchuan
# Processing Record 37 of Set 20 | ketchikan
# Processing Record 38 of Set 20 | bakal
# Processing Record 39 of Set 20 | chulumani
# Processing Record 40 of Set 20 | san quintin
# Processing Record 41 of Set 20 | nemuro
# Processing Record 42 of Set 20 | mandan
# Processing Record 43 of Set 20 | tiarei
# Processing Record 44 of Set 20 | kavieng
# Processing Record 45 of Set 20 | watsa
# Processing Record 46 of Set 20 | qiyang
# Processing Record 47 of Set 20 | sao joao da barra
# Processing Record 48 of Set 20 | mandalay
# Processing Record 49 of Set 20 | killybegs
# Processing Record 50 of Set 20 | ankazobe
# Processing Record 1 of Set 21 | ryotsu
# Processing Record 2 of Set 21 | catamarca
# Processing Record 3 of Set 21 | juneau
# Processing Record 4 of Set 21 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 21 | gewane
# Processing Record 6 of Set 21 | naze
# Processing Record 7 of Set 21 | oxford
# Processing Record 8 of Set 21 | tallahassee
# Processing Record 9 of Set 21 | churapcha
# Processing Record 10 of Set 21 | khipro
# Processing Record 11 of Set 21 | blagoyevo
# Processing Record 12 of Set 21 | san vicente
# Processing Record 13 of Set 21 | ninghai
# Processing Record 14 of Set 21 | sala
# Processing Record 15 of Set 21 | matara
# Processing Record 16 of Set 21 | anadyr
# Processing Record 17 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 21 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 21 | acari
# Processing Record 20 of Set 21 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 21 | kaitangata
# Processing Record 22 of Set 21 | antofagasta
# Processing Record 23 of Set 21 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 21 | houma
# Processing Record 25 of Set 21 | lancut
# Processing Record 26 of Set 21 | tezu
# Processing Record 27 of Set 21 | clyde river
# Processing Record 28 of Set 21 | chicama
# Processing Record 29 of Set 21 | luderitz
# Processing Record 30 of Set 21 | nioro
# Processing Record 31 of Set 21 | kayerkan
# Processing Record 32 of Set 21 | rabo de peixe
# Processing Record 33 of Set 21 | micheweni
# Processing Record 34 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 21 | kaeo
# Processing Record 36 of Set 21 | soure
# Processing Record 37 of Set 21 | saint-georges
# Processing Record 38 of Set 21 | waspan
# Processing Record 39 of Set 21 | rawson
# Processing Record 40 of Set 21 | chitral
# Processing Record 41 of Set 21 | loandjili
# Processing Record 42 of Set 21 | ilulissat
# Processing Record 43 of Set 21 | umm lajj
# Processing Record 44 of Set 21 | coquimbo
# Processing Record 45 of Set 21 | higuey
# City not found. Skipping...
# Processing Record 46 of Set 21 | bandarbeyla
# Processing Record 47 of Set 21 | comodoro rivadavia
# Processing Record 48 of Set 21 | manokwari
# Processing Record 49 of Set 21 | payo
# Processing Record 50 of Set 21 | katobu
# Processing Record 1 of Set 22 | egvekinot
# Processing Record 2 of Set 22 | saint anthony
# Processing Record 3 of Set 22 | port hedland
# Processing Record 4 of Set 22 | ucluelet
# Processing Record 5 of Set 22 | uberaba
# Processing Record 6 of Set 22 | calama
# Processing Record 7 of Set 22 | aklavik
# Processing Record 8 of Set 22 | presidencia roque saenz pena
# Processing Record 9 of Set 22 | lensk
# Processing Record 10 of Set 22 | yima
# Processing Record 11 of Set 22 | bahar
# Processing Record 12 of Set 22 | mayo
# Processing Record 13 of Set 22 | alyangula
# Processing Record 14 of Set 22 | thunder bay
# Processing Record 15 of Set 22 | piojo
# Processing Record 16 of Set 22 | kochevo
# Processing Record 17 of Set 22 | kosa
# Processing Record 18 of Set 22 | yekaterinovka
# Processing Record 19 of Set 22 | hohhot
# Processing Record 20 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 22 | sur
# Processing Record 22 of Set 22 | athabasca
# Processing Record 23 of Set 22 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 24 of Set 22 | san rafael del sur
# Processing Record 25 of Set 22 | komsomolskiy
# Processing Record 26 of Set 22 | miedzychod
# Processing Record 27 of Set 22 | yuci
# Processing Record 28 of Set 22 | oranjemund
# Processing Record 29 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 22 | cutro
# Processing Record 31 of Set 22 | tayu
# Processing Record 32 of Set 22 | mudon
# Processing Record 33 of Set 22 | erenhot
# Processing Record 34 of Set 22 | gavle
# Processing Record 35 of Set 22 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 22 | atambua
# Processing Record 37 of Set 22 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 22 | mandalgovi
# Processing Record 39 of Set 22 | cap malheureux
# Processing Record 40 of Set 22 | manoel urbano
# Processing Record 41 of Set 22 | garowe
# Processing Record 42 of Set 22 | sangar
# Processing Record 43 of Set 22 | qeshm
# Processing Record 44 of Set 22 | tabas
# Processing Record 45 of Set 22 | jumla
# Processing Record 46 of Set 22 | nantucket
# Processing Record 47 of Set 22 | nouadhibou
# Processing Record 48 of Set 22 | konevo
# Processing Record 49 of Set 22 | amuntai
# Processing Record 50 of Set 22 | floro
# Processing Record 1 of Set 23 | fortuna foothills
# Processing Record 2 of Set 23 | talnakh
# Processing Record 3 of Set 23 | la palma
# Processing Record 4 of Set 23 | marabba
# Processing Record 5 of Set 23 | hit
# Processing Record 6 of Set 23 | arlit
# Processing Record 7 of Set 23 | wajima
# Processing Record 8 of Set 23 | sovetskiy
# Processing Record 9 of Set 23 | okhotsk
# Processing Record 10 of Set 23 | mount gambier
# Processing Record 11 of Set 23 | kaduna
# Processing Record 12 of Set 23 | beringovskiy
# Processing Record 13 of Set 23 | imeni zhelyabova
# Processing Record 14 of Set 23 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 23 | acajutla
# Processing Record 16 of Set 23 | meulaboh
# Processing Record 17 of Set 23 | barabinsk
# Processing Record 18 of Set 23 | dosso
# Processing Record 19 of Set 23 | grindavik
# Processing Record 20 of Set 23 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 23 | bogovarovo
# Processing Record 22 of Set 23 | la orilla
# Processing Record 23 of Set 23 | yacuiba
# Processing Record 24 of Set 23 | burhar
# Processing Record 25 of Set 23 | kamyshin
# Processing Record 26 of Set 23 | esmeraldas
# Processing Record 27 of Set 23 | inhambane
# Processing Record 28 of Set 23 | vestmanna
# Processing Record 29 of Set 23 | ozernovskiy
# Processing Record 30 of Set 23 | maumere
# Processing Record 31 of Set 23 | camapua
# Processing Record 32 of Set 23 | goroka
# Processing Record 33 of Set 23 | bubaque
# Processing Record 34 of Set 23 | sorland
# Processing Record 35 of Set 23 | sehithwa
# Processing Record 36 of Set 23 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 23 | baykit
# Processing Record 38 of Set 23 | poronaysk
# Processing Record 39 of Set 23 | kununurra
# Processing Record 40 of Set 23 | morshansk
# Processing Record 41 of Set 23 | brownsville
# Processing Record 42 of Set 23 | kisangani
# Processing Record 43 of Set 23 | san carlos de bariloche
# Processing Record 44 of Set 23 | puerto escondido
# Processing Record 45 of Set 23 | bilibino
# Processing Record 46 of Set 23 | barahona
# Processing Record 47 of Set 23 | methven
# Processing Record 48 of Set 23 | kommunisticheskiy
# Processing Record 49 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 24 | fort frances
# Processing Record 2 of Set 24 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 24 | honiara
# Processing Record 4 of Set 24 | monrovia
# Processing Record 5 of Set 24 | nerchinskiy zavod
# Processing Record 6 of Set 24 | the valley
# Processing Record 7 of Set 24 | straumen
# Processing Record 8 of Set 24 | kailua
# Processing Record 9 of Set 24 | hasanabad
# Processing Record 10 of Set 24 | novobirilyussy
# Processing Record 11 of Set 24 | calvia
# Processing Record 12 of Set 24 | flin flon
# Processing Record 13 of Set 24 | emba
# Processing Record 14 of Set 24 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 24 | brodokalmak
# Processing Record 16 of Set 24 | shihezi
# Processing Record 17 of Set 24 | rincon
# Processing Record 18 of Set 24 | talaya
# Processing Record 19 of Set 24 | belomorsk
# Processing Record 20 of Set 24 | gazli
# Processing Record 21 of Set 24 | glendora
# Processing Record 22 of Set 24 | yabelo
# Processing Record 23 of Set 24 | stanger
# Processing Record 24 of Set 24 | port hueneme
# Processing Record 25 of Set 24 | capalonga
# Processing Record 26 of Set 24 | berlevag
# Processing Record 27 of Set 24 | havelock
# Processing Record 28 of Set 24 | demyanovo
# Processing Record 29 of Set 24 | severo-yeniseyskiy
# Processing Record 30 of Set 24 | palpa
# Processing Record 31 of Set 24 | adamas
# Processing Record 32 of Set 24 | maceio
# Processing Record 33 of Set 24 | lubbock
# Processing Record 34 of Set 24 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 24 | tura
# Processing Record 36 of Set 24 | takoradi
# Processing Record 37 of Set 24 | nikel
# Processing Record 38 of Set 24 | pedasi
# Processing Record 39 of Set 24 | amapa
# Processing Record 40 of Set 24 | kizner
# Processing Record 41 of Set 24 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 24 | artyom
# Processing Record 43 of Set 24 | port hardy
# Processing Record 44 of Set 24 | henties bay
# Processing Record 45 of Set 24 | phuket
# Processing Record 46 of Set 24 | marsh harbour
# Processing Record 47 of Set 24 | yashan
# Processing Record 48 of Set 24 | gracac
# Processing Record 49 of Set 24 | chubbuck
# Processing Record 50 of Set 24 | brandon
# Processing Record 1 of Set 25 | wahiawa
# Processing Record 2 of Set 25 | husavik
# Processing Record 3 of Set 25 | itoman
# Processing Record 4 of Set 25 | kutum
# Processing Record 5 of Set 25 | jurm
# Processing Record 6 of Set 25 | bismarck
# Processing Record 7 of Set 25 | onguday
# Processing Record 8 of Set 25 | olinda
# Processing Record 9 of Set 25 | hashtrud
# Processing Record 10 of Set 25 | borovskoy
# Processing Record 11 of Set 25 | sarangani
# Processing Record 12 of Set 25 | labuan
# Processing Record 13 of Set 25 | lavrentiya
# Processing Record 14 of Set 25 | anori
# Processing Record 15 of Set 25 | san julian
# Processing Record 16 of Set 25 | padang
# Processing Record 17 of Set 25 | kloulklubed
# Processing Record 18 of Set 25 | shellbrook
# Processing Record 19 of Set 25 | chernyy yar
# Processing Record 20 of Set 25 | azangaro
# Processing Record 21 of Set 25 | narsaq
# Processing Record 22 of Set 25 | broken hill
# Processing Record 23 of Set 25 | bentiu
# Processing Record 24 of Set 25 | kendari
# Processing Record 25 of Set 25 | krasnoselkup
# Processing Record 26 of Set 25 | hualmay
# Processing Record 27 of Set 25 | baherden
# Processing Record 28 of Set 25 | salinas
# Processing Record 29 of Set 25 | bushehr
# Processing Record 30 of Set 25 | vila
# Processing Record 31 of Set 25 | quatre cocos
# Processing Record 32 of Set 25 | adrar
# Processing Record 33 of Set 25 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 25 | tromso
# Processing Record 35 of Set 25 | verkhnyaya inta
# Processing Record 36 of Set 25 | leiyang
# Processing Record 37 of Set 25 | rajula
# Processing Record 38 of Set 25 | port keats
# Processing Record 39 of Set 25 | ust-uda
# Processing Record 40 of Set 25 | greaca
# Processing Record 41 of Set 25 | vitim
# Processing Record 42 of Set 25 | gigmoto
# Processing Record 43 of Set 25 | kinshasa
# Processing Record 44 of Set 25 | papasquiaro
# City not found. Skipping...
# Processing Record 45 of Set 25 | ahuimanu
# Processing Record 46 of Set 25 | grand island
# Processing Record 47 of Set 25 | linjiang
# Processing Record 48 of Set 25 | wanlaweyn
# Processing Record 49 of Set 25 | arrifes
# Processing Record 50 of Set 25 | palmer
# Processing Record 1 of Set 26 | prince rupert
# Processing Record 2 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 26 | khovu-aksy
# Processing Record 4 of Set 26 | jalingo
# Processing Record 5 of Set 26 | suntar
# Processing Record 6 of Set 26 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 26 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 26 | hudson bay
# Processing Record 9 of Set 26 | novikovo
# Processing Record 10 of Set 26 | atar
# Processing Record 11 of Set 26 | launceston
# Processing Record 12 of Set 26 | santa cruz
# Processing Record 13 of Set 26 | assiniboia
# Processing Record 14 of Set 26 | sinnamary
# Processing Record 15 of Set 26 | hami
# Processing Record 16 of Set 26 | krasnaya gora
# Processing Record 17 of Set 26 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 26 | davenport
# Processing Record 19 of Set 26 | jaffna
# Processing Record 20 of Set 26 | xichang
# Processing Record 21 of Set 26 | ouango
# Processing Record 22 of Set 26 | kudamatsu
# Processing Record 23 of Set 26 | serik
# Processing Record 24 of Set 26 | ambilobe
# Processing Record 25 of Set 26 | necochea
# Processing Record 26 of Set 26 | tete
# Processing Record 27 of Set 26 | hambantota
# Processing Record 28 of Set 26 | santona
# Processing Record 29 of Set 26 | burns lake
# Processing Record 30 of Set 26 | abu samrah
# Processing Record 31 of Set 26 | sungaipenuh
# Processing Record 32 of Set 26 | ulladulla
# Processing Record 33 of Set 26 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 26 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 26 | punta gorda
# Processing Record 36 of Set 26 | saint-augustin
# Processing Record 37 of Set 26 | bodmin
# Processing Record 38 of Set 26 | sulya
# Processing Record 39 of Set 26 | jaisalmer
# Processing Record 40 of Set 26 | shimoda
# Processing Record 41 of Set 26 | kieta
# Processing Record 42 of Set 26 | berdigestyakh
# Processing Record 43 of Set 26 | ponta delgada
# Processing Record 44 of Set 26 | bloemfontein
# Processing Record 45 of Set 26 | westport
# Processing Record 46 of Set 26 | neftcala
# Processing Record 47 of Set 26 | palembang
# Processing Record 48 of Set 26 | salaya
# Processing Record 49 of Set 26 | garoua boulai
# Processing Record 50 of Set 26 | cordoba
# Processing Record 1 of Set 27 | pillaro
# Processing Record 2 of Set 27 | pangnirtung
# Processing Record 3 of Set 27 | jiroft
# City not found. Skipping...
# Processing Record 4 of Set 27 | nishihara
# Processing Record 5 of Set 27 | kardymovo
# Processing Record 6 of Set 27 | kilakarai
# Processing Record 7 of Set 27 | lebedyan
# Processing Record 8 of Set 27 | ahipara
# Processing Record 9 of Set 27 | tessalit
# Processing Record 10 of Set 27 | meadow lake
# Processing Record 11 of Set 27 | porgera
# Processing Record 12 of Set 27 | prescott
# Processing Record 13 of Set 27 | mahajanga
# Processing Record 14 of Set 27 | pacific grove
# Processing Record 15 of Set 27 | mushie
# Processing Record 16 of Set 27 | hamilton
# Processing Record 17 of Set 27 | broome
# Processing Record 18 of Set 27 | puro
# Processing Record 19 of Set 27 | jieshi
# Processing Record 20 of Set 27 | billings
# Processing Record 21 of Set 27 | mahanoro
# Processing Record 22 of Set 27 | machico
# Processing Record 23 of Set 27 | mandurah
# Processing Record 24 of Set 27 | fairbanks
# Processing Record 25 of Set 27 | deputatskiy
# Processing Record 26 of Set 27 | ledec
# Processing Record 27 of Set 27 | breves
# Processing Record 28 of Set 27 | adre
# Processing Record 29 of Set 27 | hofn
# Processing Record 30 of Set 27 | acapulco
# Processing Record 31 of Set 27 | herat
# Processing Record 32 of Set 27 | port augusta
# Processing Record 33 of Set 27 | bechem
# Processing Record 34 of Set 27 | eureka
# Processing Record 35 of Set 27 | labuhan
# Processing Record 36 of Set 27 | general roca
# Processing Record 37 of Set 27 | zyryanka
# Processing Record 38 of Set 27 | baturaja
# Processing Record 39 of Set 27 | vredendal
# Processing Record 40 of Set 27 | alice springs
# Processing Record 41 of Set 27 | chatsu
# City not found. Skipping...
# Processing Record 42 of Set 27 | sylva
# Processing Record 43 of Set 27 | tashtyp
# Processing Record 44 of Set 27 | bosaso
# Processing Record 45 of Set 27 | novo aripuana
# Processing Record 46 of Set 27 | charters towers
# Processing Record 47 of Set 27 | coos bay
# Processing Record 48 of Set 27 | shintomi
# Processing Record 49 of Set 27 | vila do maio
# Processing Record 50 of Set 27 | tabou
# --------------------------------
# Data Retreival Complete
# --------------------------------

# %%
# Convert to a Pandas DataFrame 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Christchurch      NZ -43.5333  172.6333     38.95        72          31
# 1          Plastun      RU  44.7561  136.2939     45.64        95          58
# 2           Kodiak      US  57.7900 -152.4072     44.73        78         100
# 3      New Norfolk      AU -42.7826  147.0587     45.90        82           8
# 4         Khatanga      RU  71.9667  102.5000     28.90        89          82
# 5           Ossora      RU  59.2353  163.0719     33.82        99         100
# 6        Cape Town      ZA -33.9258   18.4232     60.28        70          40
# 7       Walvis Bay      NA -22.9575   14.5053     61.09        71           0
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        88          75
# 9           Barrow      US  71.2906 -156.7887     28.42       100         100
#
#    Wind Speed Weather Description
# 0        4.61    scattered clouds
# 1        2.91       broken clouds
# 2        6.82     overcast clouds
# 3        2.26           clear sky
# 4        9.71       broken clouds
# 5        1.70     overcast clouds
# 6       10.36    scattered clouds
# 7       23.62           clear sky
# 8       19.57       broken clouds
# 9       12.66                 fog

# %%
# Create the output file (CSV)
output_data_file = "../Weather_Database/Updated_Cities.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
